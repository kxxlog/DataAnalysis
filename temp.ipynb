# %%
import csv
f = open('C:\jupyter\seoul.csv', 'r', encoding='cp949')
data = csv.reader(f, delimiter=',')
for row in data:
    print(row)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['\t2024-11-17', '108', '7', '2.1', '14.4']
# ['\t2024-11-18', '108', '2.8', '-0.7', '7.9']
# ['\t2024-11-19', '108', '5.7', '0.3', '11.3']
# ['\t2024-11-20', '108', '6.5', '2.4', '9.6']
# ['\t2024-11-21', '108', '9.7', '6', '14.1']
# ['\t2024-11-22', '108', '6.2', '3.3', '10.6']
# ['\t2024-11-23', '108', '6.4', '1.5', '12.6']
# ['\t2024-11-24', '108', '7.4', '2.6', '14.2']
# ['\t2024-11-25', '108', '10.1', '3.6', '15.4']
# ['\t2024-11-26', '108', '5.8', '1', '12.7']
# ['\t2024-11-27', '108', '-0.4', '-1.3', '1.2']
# ['\t2024-11-28', '108', '0.8', '-1.7', '3.4']
# ['\t2024-11-29', '108', '0.2', '-3.4', '3.4']
# ['\t2024-11-30', '108', '2.5', '-0.5', '5.6']
# ['\t2024-12-01', '108', '5.2', '1.6', '8.2']
# ['\t2024-12-02', '108', '6.4', '0.6', '13']
# ['\t2024-12-03', '108', '1.3', '-2.4', '5.2']
# ['\t2024-12-04', '108', '3.1', '-0.6', '6.9']
# ['\t2024-12-05', '108', '3.9', '-0.1', '8.8']
# ['\t2024-12-06', '108', '2.1', '-0.4', '5.2']
# ...

# %%
import csv
f = open('C:\jupyter\seoul.csv', 'r', encoding='cp949')
data = csv.reader(f, delimiter=',')
header = next(data)
print(header)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
f = open('C:\jupyter\seoul.csv', 'r', encoding='cp949')
data = csv.reader(f, delimiter=',')
header = next(data)
max_temp = -999
max_date = ''
for row in data:
    if row[-1] == '':
        row[-1] = -999
    row[-1] = float(row[-1])
    if max_temp < row[-1]:
        max_date = row[0]
        max_temp = row[-1]

f.close()
print('기상 관측이 가장 높았던 날은 ',max_date,'이고, 온도는 ',max_temp,' 입니다')
# Out:
# 기상 관측이 가장 높았던 날은  	2024-11-25 이고, 온도는  15.4  입니다

# %%
import matplotlib.pyplot as plt
plt.title('plotting')
plt.plot([10,20,30,40])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title('legend')
plt.plot([10,20,30,40], label='asc')
plt.plot([40,30,20,10], label='desc')
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('C:\jupyter\seoul.csv', 'r', encoding='cp949')
data = csv.reader(f, delimiter=',')
next(data)
result = []
for row in data:
    if row[-1] != '' :
        result.append(float(row[-1]))
plt.plot(result, 'r')
plt.show()
f.close()

# %%
import random
import matplotlib.pyplot as plt
result = []
for i in range(13):
    result.append(random.randint(1,1000))

print(sorted(result))

plt.boxplot(result)
plt.show()
# Out:
# [9, 39, 107, 168, 296, 371, 467, 507, 532, 795, 869, 932, 986]

# %%
import csv
import matplotlib.pyplot as plt
f = open('C:\jupyter\seoul_temp.csv', encoding='cp949')
data = csv.reader(f)
next(data)

result=[]

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
        
plt.boxplot(result) # 상자 그림으로 나타내기
plt.show()

# %%
import csv
f = open('C:/jupyter/age.csv')
data = csv.reader(f)

for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            print(i)
# Out:
# 326
# 334
# 406
# 413
# 389
# 408
# 417
# 434
# 411
# 387
# 420
# 383
# 354
# 357
# 340
# 338
# 349
# 339
# 407
# 380
# 390
# 453
# 424
# 516
# 451
# 466
# 448
# 484
# 471
# 476
# 558
# 541
# 579
# 619
# 638
# 740
# 756
# 792
# 745
# 789
# 671
# 687
# 700
# 636
# 726
# 691
# 657
# 619
# 649
# 585
# 579
# 470
# 522
# 534
# 563
# 445
# 511
# 569
# 572
# 513
# 532
# 456
# 426
# 497
# 379
# 384
# 399
# 279
# 289
# 276
# 268
# 271
# 223
# 170
# 150
# 154
# 177
# 140
# 126
# 114
# 121
# 97
# 86
# 80
# 59
# 48
# 44
# 43
# 28
# 29
# 22
# 15
# 13
# 12
# 5
# 8
# 5
# 4
# 2
# 3
# 7

# %%
import csv
import matplotlib.pyplot as plt
f = open('C:/jupyter/age.csv')
data = csv.reader(f)
result =[]
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i))

plt.style.use('ggplot')
plt.plot(result)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('C:/jupyter/age.csv')
data = csv.reader(f)
name = input('인구 구조가 알고 싶은 지역의 이름을 입력해주세요')
result =[]
for row in data:
    if '신도림' in row[0]:
        for i in row[3:]:
            result.append(int(i.replace(',','')))

plt.style.use('ggplot')
plt.rc('font', family='Malgun Gothic')
plt.title(name+' 지역의 인구 구조')
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름을 입력해주세요광장동

# %%
import csv
from matplotlib import font_manager as fm
f = open('C:/jupyter/gender.csv', encoding='cp949')
data = csv.reader(f)

m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(-int(i.replace(',', '')))
        for i in row[106:] :
            f.append(int(i.replace(',', '')))
        break

import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize = (10,5), dpi=300)
# plt.rc('font', family = 'Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False
plt.title(name + ' 지역의 남녀 성별 인구 분포')
plt.barh(range(101), m, label = 'Male')
plt.barh(range(101), f, label = 'Female')
plt.legend()
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 제주특별자치도

# %%
import matplotlib.pyplot as plt

plt.rc('font', family = 'NanumGothic')
size = [2441, 2312, 1031, 1233]
label = ['A형','B형','AB형', 'O형']
plt.axis('equal')
plt.pie(size, labels = label) 
plt.show()

# %%
plt.rc('font', family = 'NanumGothic')
size = [2441, 2312, 1031, 1233]
label = ['A형','B형','AB형', 'O형']
color = ['darkmagenta', 'deeppink', 'hotpink', 'pink']
plt.axis('equal')
plt.pie(size, labels = label, autopct = '%.1f%%', explode = (0,0,0.1,0), colors = color)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'NanumGothic')
size = [2441, 2312, 1031, 1233]
label = ['A형','B형','AB형', 'O형']
plt.axis('equal')
plt.pie(size, labels = label, autopct = '%.1f%%')   # 비율 및 범례 추가
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors


colors = dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS)

# Sort colors by hue, saturation, value and name.
by_hsv = sorted((tuple(mcolors.rgb_to_hsv(mcolors.to_rgba(color)[:3])), name)
                for name, color in colors.items())
sorted_names = [name for hsv, name in by_hsv]

n = len(sorted_names)
ncols = 4
nrows = n // ncols

fig, ax = plt.subplots(figsize=(9, 8), dpi = 300)

# Get height and width
X, Y = fig.get_dpi() * fig.get_size_inches()
h = Y / (nrows + 1)
w = X / ncols

for i, name in enumerate(sorted_names):
    row = i % nrows
    col = i // nrows
    y = Y - (row * h) - h

    xi_line = w * (col + 0.05)
    xf_line = w * (col + 0.25)
    xi_text = w * (col + 0.3)

    ax.text(xi_text, y, name, fontsize=(10),
            horizontalalignment='left',
            verticalalignment='center')

    ax.hlines(y + h * 0.1, xi_line, xf_line,
              color=colors[name], linewidth=(6))

ax.set_xlim(0, X)
ax.set_ylim(0, Y)
ax.set_axis_off()

fig.subplots_adjust(left=0, right=1,
                    top=1, bottom=0,
                    hspace=0, wspace=0)
plt.show()

# %%
import csv
from matplotlib import font_manager as fm
f = open('C:/jupyter/gender.csv', encoding='cp949')
data = csv.reader(f)

size = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        m = 0
        f = 0
        for i in range(101) :
            m += int(row[i+3])
            f += int(row[i+106])
        break
size.append(m)
size.append(f)

import matplotlib.pyplot as plt
plt.rc('font', family ='NanumGothic')
color = ['crimson', 'darkcyan']
plt.axis('equal')
plt.pie(size, labels = ['남','여'], autopct ='%.1f%%', colors = color, startangle =90)
plt.title(name + ' 지역의 남녀 성별 비율')
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 청담동

# %%
import csv
from matplotlib import font_manager as fm
f = open('C:/jupyter/gender.csv', encoding='cp949')
data = csv.reader(f)
m = []
f = []
name = input('궁금한 동네를 입력해주세요:')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            m.append(int(row[i])) # 남성 데이터를 저장하기
            f.append(int(row[i+103])) # 여성 테이터 저장하기
        break
plt.plot(m, label='Male')
plt.plot(f, label='Female')
plt.legend()
plt.show()
# Out:
# 궁금한 동네를 입력해주세요:청담동

# %%
import csv
from matplotlib import font_manager as fm
f = open('C:/jupyter/gender.csv', encoding='cp949')
data = csv.reader(f)
result = []
name = input('궁금한 동네를 입력해주세요:')
for row in data:
    if name in row[0]:
        for i in range(3, 104):
            result.append(int(row[i]) - int(row[i+103]))
        break
plt.figure(figsize=(10, 5))     
plt.bar(range(101), result)
plt.show()
# Out:
# 궁금한 동네를 입력해주세요:청담동

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40])
plt.show()

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c = range(4))
plt.colorbar()
plt.show()

# %%
plt.style.use('ggplot')
plt.scatter([1,2,3,4], [10,30,20,40], s = [30,60,90,120], c =range(4), cmap='jet')
plt.colorbar()
plt.show()

# %%
import random

x = []
y = []
size = []
for i in range(100) : 
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
    
plt.style.use('ggplot')
plt.scatter(x, y, s = size)
plt.show()

# %%
import random

x = []
y = []
size = []
for i in range(100) : 
    x.append(random.randint(50,100))
    y.append(random.randint(50,100))
    size.append(random.randint(10,100))
    
plt.scatter(x, y, s = size, c = size, cmap='jet')
plt.colorbar()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
f = open('C:/jupyter/gender.csv')
data = csv.reader(f)

m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(int(i.replace(',', '')))
        for i in row[106:] :
            f.append(int(i.replace(',', '')))
        break

plt.style.use('ggplot')
plt.scatter(m, f)
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 청담동

# %%
import csv
import matplotlib.pyplot as plt
f = open('C:/jupyter/gender.csv')
data = csv.reader(f)
m = []
f = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        for i in row[3:104] :
            m.append(int(i.replace(',', '')))
        for i in row[106:] :
            f.append(int(i.replace(',', '')))
        break

plt.style.use('ggplot')
plt.scatter(m, f, c =range(101), alpha=0.5, cmap='jet') # 컬러맵 적용
plt.colorbar()
plt.plot(range(max(m)),range(max(m)), 'g') # 추세선 추가
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 청담동

# %%
import csv
import matplotlib.pyplot as plt
import math
f = open('C:/jupyter/gender.csv')
data = csv.reader(f)
m = []
f = []
size = []

name = input('찾고 싶은 지역의 이름을 알려주세요 : ')
for row in data :
    if name in row[0] :
        for i in range(3,104) : 
            m.append(int(row[i]))
            f.append(int(row[i+103]))
            size.append(math.sqrt(int(row[i]) + int(row[i+103])))
        break

plt.style.use('ggplot')
plt.rc('font',family='NanumGothic')
plt.figure(figsize = (10,5), dpi=300)            
plt.title(name+' 지역의 성별 인구 그래프')
plt.scatter(m, f, s = size, c = range(101), alpha=0.5, cmap='jet')
plt.colorbar()
plt.plot(range(max(m)),range(max(m)), 'g')
plt.xlabel('남성 인구 수')
plt.ylabel('여성 인구 수')
plt.show()
# Out:
# 찾고 싶은 지역의 이름을 알려주세요 : 청담동

# %%
import csv

f = open('C:/jupyter/subwaytime.csv')
data = csv.reader(f)
next(data)
next(data)
mx = 0
mx_station = ''
t = int(input('몇 시의 승차 인원이 가장 많은 역이 궁금하세요? :'))
# 헤더를 제외하고 4번~7번 열을 정수(int)로 변환
for row in data:
    row[4:] = map(int, row[4:])
    a = row[4+(t-4)*2]
    if a > mx :
        mx = a
        mx_station = row[3]+'('+row[1]+')'
print(mx_station, mx)
# Out:
# 몇 시의 승차 인원이 가장 많은 역이 궁금하세요? :23
# 강남(2호선) 145504

# %%
import csv
import matplotlib.pyplot as plt
f = open('C:/jupyter/subwaytime.csv')
data = csv.reader(f)
next(data)
next(data)

s_in = [0]*24
s_out = [0]*24
for row in data:
    row[4:] = map(int, row[4:])
    for i in range(24):
        s_in[i] += row[4+i*2]
        s_out[i] += row[5+i*2]
plt.rc('font', family='Malgun Gothic')
plt.title('지하철 시간대별 승하차 인원 추이')
plt.plot(s_in, label='승차')
plt.plot(s_out, label='하차')
plt.legend()
plt.xticks(range(24), range(4,28))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0., 5., 0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()
